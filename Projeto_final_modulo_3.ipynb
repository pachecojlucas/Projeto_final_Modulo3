# %%
import pandas as pd

# %%
net = pd.read_csv(r"C:\Users\joao-\Downloads\netflix_titles.csv")
display(net)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
net.tail(3)
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
# ...

# %%
net.shape
# Out:
# (8807, 12)

# %%
list(net.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
net.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
net.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
net.describe(include=['object'])
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %%
net[['director','country','listed_in']].value_counts().head(10)
# Out:
# director                country        listed_in
# Marcus Raboy            United States  Stand-Up Comedy                                             14
# Jay Karas               United States  Stand-Up Comedy                                             13
# Jay Chapman             United States  Stand-Up Comedy                                             11
# Raúl Campos, Jan Suter  Mexico         Stand-Up Comedy                                              9
# Shannon Hartman         United States  Stand-Up Comedy                                              8
# Troy Miller             United States  Stand-Up Comedy                                              7
# Lance Bangs             United States  Stand-Up Comedy                                              7
# Toshiya Shinohara       Japan          Action & Adventure, Anime Features, International Movies     7
# Ryan Polito             United States  Stand-Up Comedy                                              7
# ...

# %%
net[['director','country','listed_in','release_year']].value_counts().head(10)
# Out:
# director                country         listed_in                        release_year
# Marcus Raboy            United States   Stand-Up Comedy                  2017            6
# Raúl Campos, Jan Suter  Argentina       Stand-Up Comedy                  2018            5
# Edward Cotterill        United Kingdom  Documentaries                    2017            4
# Matt Askem              United States   Documentaries, Music & Musicals  2018            4
# Raúl Campos, Jan Suter  Mexico          Stand-Up Comedy                  2017            3
# Jay Chapman             United States   Stand-Up Comedy                  2017            3
#                                                                          2014            3
# Marcus Raboy            United States   Stand-Up Comedy                  2018            3
# Linda Mendoza           United States   Stand-Up Comedy                  2019            3
# ...

# %%
list_colunas = {'director','country','listed_in','release_year'}

# %%
for column in list_colunas:
        print(f'\n #### {column} ####')
        print(net[column].value_counts().head(10))
# Out:
#  #### country ####
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64
#
#  #### director ####
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64
#
#  #### release_year ####
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: release_year, dtype: int64
#
#  #### listed_in ####
# Dramas, International Movies                        362
# ...

# %%
net['director'].value_counts().index[0]
# Out:
# 'Rajiv Chilaka'

# %%
net['country'].value_counts().index[1]
# Out:
# 'India'

# %%
net['release_year'].value_counts().index[0]
# Out:
# 2018

# %%
net.isnull().sum()[net.isnull().sum()>0]
# Out:
# director      2634
# cast           825
# country        831
# date_added      10
# rating           4
# duration         3
# dtype: int64

# %%
round(net.isna().sum()/net.shape[0]*100,2)
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        29.91
# cast             9.37
# country          9.44
# date_added       0.11
# release_year     0.00
# rating           0.05
# duration         0.03
# listed_in        0.00
# description      0.00
# dtype: float64

# %%
net.notnull().sum()
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
round(net.notna().sum()/net.shape[0]*100,2)
# Out:
# show_id         100.00
# type            100.00
# title           100.00
# director         70.09
# cast             90.63
# country          90.56
# date_added       99.89
# release_year    100.00
# rating           99.95
# duration         99.97
# listed_in       100.00
# description     100.00
# dtype: float64

# %%
values = {'director':'NA','country':'NA'}
net[['director','country']] = net[['director','country']].fillna(value= values)

# %%
net.drop(columns=['cast','rating','description'], inplace=True)

# %%
net.dropna(inplace=True)

# %%
display(net)
# Out:
#      show_id     type                  title         director        country  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1         s2  TV Show          Blood & Water               NA   South Africa
# 2         s3  TV Show              Ganglands  Julien Leclercq             NA
# 3         s4  TV Show  Jailbirds New Orleans               NA             NA
# 4         s5  TV Show           Kota Factory               NA          India
# ...      ...      ...                    ...              ...            ...
# 8802   s8803    Movie                 Zodiac    David Fincher  United States
# 8803   s8804  TV Show            Zombie Dumb               NA             NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer  United States
# 8805   s8806    Movie                   Zoom     Peter Hewitt  United States
# 8806   s8807    Movie                 Zubaan      Mozez Singh          India
#
#      date_added  release_year   duration  \
# ...

# %%
net['date_added'] = pd.to_datetime(net['date_added'])

# %%
net['dia'] = net['date_added'].dt.day
net['mês'] = net['date_added'].dt.month
net['ano'] = net['date_added'].dt.year

# %%
list_col_temps = {'dia','mês','ano'}

# %%
for column in list_col_temps:
        print(f'\n #### {column} ####')
        print(net[column].value_counts().head(10))
# Out:
#  #### dia ####
# 1     2212
# 15     686
# 2      325
# 16     288
# 31     274
# 20     249
# 19     243
# 5      231
# 22     230
# 10     214
# Name: dia, dtype: int64
#
#  #### mês ####
# 7     827
# 12    813
# 9     769
# 4     763
# 10    760
# 8     754
# 3     742
# 1     738
# 6     728
# 11    705
# Name: mês, dtype: int64
#
#  #### ano ####
# 2019    2016
# 2020    1879
# 2018    1649
# 2021    1498
# 2017    1187
# 2016     427
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# Name: ano, dtype: int64

# %%
net['dia'].value_counts().index[0]
# Out:
# 1

# %%
net['mês'].value_counts().index[-1]
# Out:
# 2

# %%
net['ano'].value_counts().index[0]
# Out:
# 2019

# %%
net[net['listed_in'].str.contains('Drama')]
# Out:
#      show_id     type               title             director  \
# 1         s2  TV Show       Blood & Water                   NA
# 5         s6  TV Show       Midnight Mass        Mike Flanagan
# 7         s8    Movie             Sankofa         Haile Gerima
# 9        s10    Movie        The Starling       Theodore Melfi
# 12       s13    Movie        Je Suis Karl  Christian Schwochow
# ...      ...      ...                 ...                  ...
# 8799   s8800    Movie               Zenda       Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                   NA
# 8801   s8802    Movie             Zinzana      Majid Al Ansari
# 8802   s8803    Movie              Zodiac        David Fincher
# 8806   s8807    Movie              Zubaan          Mozez Singh
#
#                                                 country date_added  \
# 1                                          South Africa 2021-09-24
# 5                                                    NA 2021-09-24
# ...

# %%
net['type'].value_counts()
# Out:
# Movie      6128
# TV Show    2666
# Name: type, dtype: int64

# %%
round(net['type'].value_counts()/net.shape[0]*100,2)
# Out:
# Movie      69.68
# TV Show    30.32
# Name: type, dtype: float64
